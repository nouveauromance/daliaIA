# %% [markdown]
# # **Planejamento da IA do Dália**
#
# Ana Beatriz de Oliveira Alves
#
# Natali Mendonça Dau
#
# Rayane Barros Mendes

# %% [markdown]
# ## Contexto

# %% [markdown]
# ## Objetivo

# %% [markdown]
# ## Escopo
